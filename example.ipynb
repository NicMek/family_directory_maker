# %%
from main import Family
from pathlib import Path

BASE_PATH = Path.cwd().parent

# %% [markdown]
# Building a folder structure for one family.

# %%
family1 = Family(
        "John",
        "Smith",
        "Jane",
        "Doe",
        ["Alice","Bob"]
    )

family1.build_folder(BASE_PATH)

# %% [markdown]
# Building multiple folder structures from an excel file.
